# %%
# %run 'Functions.ipynb'

# %% [markdown]
# ## All

# %%
x, y = unzip(hist_data())
plt.plot(x, y)

# %%
total = np.sum(y)
precise = np.sum(y[y <= 500])
# % of non-spiky data
precise / total * 100
# Out:
# 15.866153470848129

# %% [markdown]
# ## 1990-2017

# %%
x, y = unzip(hist_data(None, '1990-01-01', '2017-01-01'))
plt.plot(x, y)

# %%
x, y = unzip(hist_data(None, '1990-01-01', '2017-01-01'))
y[y >= 500] = 0
plt.plot(x, y)

# %% [markdown]
# ## 1990-2005

# %%
x, y = unzip(hist_data(None, '1990-01-01', '2005-01-01'))
plt.plot(x, y)

# %%
x, y = unzip(hist_data(None, '1990-01-01', '2005-01-01'))
y[y >= 500] = 0
plt.plot(x, y)

# %% [markdown]
# ## 2013-2017

# %%
x, y = unzip(hist_data(None, '2013-01-01', '2017-01-01'))
plt.plot(x, y)

# %%
x, y = unzip(hist_data(None, '2013-01-01', '2017-01-01'))
y[y >= 500] = 0
plt.plot(x, y)

# %%
x, y = unzip(hist_data('proton', '1990-01-01', '2017-01-01'))
x2, y2 = unzip(hist_data('neutron', '1990-01-01', '2017-01-01'))
plt.plot(x, y)
plt.plot(x2, y2, 'r')

# %%
x, y = unzip(hist_data('higgs', '1990-01-01', '2017-01-01'))
plt.plot(x, y)

# %% [markdown]
# ## Selected period 2013-02-01 to 2016-06-01

# %%
x, y = unzip(hist_data_selected(None, '2013-02-16', '2016-06-01', 'day'))
plt.plot(x, y)

# %%
sum(y)
# Out:
# 92793

# %%
fft_general = np.fft.rfft(y)

# %%
plt.plot(np.abs(fft_general))

# %%
fdom = np.abs(fft_general)
fdom[fdom < 10000] = 0
np.argsort(-fdom)[:5]
# Out:
# array([  0, 172, 171, 343, 398])

# %%
fcut = 0.1
N = 50
h = np.sinc(2 * fcut * (np.arange(N) - (N - 1) / 2.))
h *= np.blackman(N)
h /= np.sum(h)

# %%
plt.plot(np.abs(np.fft.rfft(h)))

# %%
plt.plot(sp.signal.lfilter(h, 1.0, y))
